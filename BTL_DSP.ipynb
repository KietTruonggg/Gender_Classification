# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
from tensorflow.keras.optimizers import SGD,Adam
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
import cv2
from sklearn.model_selection import train_test_split
import cvlib as cv
import os
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
data_path='dataset'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels))

print(label_dict)
# Out:
# {'man': 0, 'woman': 1}

# %%
#Preprocess data
img_size=96
data=[]
label=[]

for category in categories:
    folder_path = os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)
        face, confidence = cv.detect_face(img)
        gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)     
        for idx, f in enumerate(face):   
            (startX, startY) = f[0], f[1]
            (endX, endY) = f[2], f[3]
            face_crop = np.copy(gray[startY:endY,startX:endX])
            
            if (face_crop.shape[0]) < 10 or (face_crop.shape[1]) < 10:
                continue
                
            resized=cv2.resize(gray,(img_size,img_size))
            data.append(resized)
            label.append(label_dict[category])

print(f"Number of faces ={len(data)}")
# Out:
# Number of faces =5164

# %%
plt.figure()
plt.grid(None)
plt.imshow(data[6],cmap = 'gray')
plt.show()

# %%
#Normalization
new_data=np.array(data)/255.0
#One-hot coding
new_label=np_utils.to_categorical(label)
np.save('./training/data',new_data)
np.save('./training/label',new_label)

# %%
#Load preprocessed-data
data=np.load('./training/data.npy')
label=np.load('./training/label.npy')
data = data.reshape(data.shape[0],96,96,1)

# %%
# Split data into 3 parts: Train,Validation,Test data
train_data,test_data,train_label,test_label=train_test_split(data,label,test_size=0.1)
train_data,val_data,train_label,val_label = train_test_split(train_data,train_label,test_size=0.1)
print(f"Length of Train data: {len(train_data)}")
print(f"Length of Test data: {len(test_data)}")
print(f"Length of Validation data: {len(val_data)}")
# Out:
# Length of Train data: 4182
# Length of Test data: 517
# Length of Validation data: 465

# %%
epochs = 100
sizeOfFilter1=(3,3)
sizeOfFilter2=(3,3)

sizeOfPool=(2,2)
noOfNode=256

model=Sequential()
model.add((Conv2D(32, sizeOfFilter1, input_shape=(96,96,1),activation='relu')))
model.add(BatchNormalization())
model.add((Conv2D(32, sizeOfFilter1,activation='relu')))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=sizeOfPool))
model.add(Dropout(0.05))

model.add((Conv2D(64, sizeOfFilter2,activation='relu')))
model.add(BatchNormalization())
model.add((Conv2D(64, sizeOfFilter2,activation='relu')))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=sizeOfPool))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(noOfNode, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.15))
model.add(Dense(2, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])

# %%
# Image augmentation
datagen = ImageDataGenerator(rotation_range=10, width_shift_range=0.1,
                         height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                         horizontal_flip=True, fill_mode="nearest")

# prepare iterator
it_train = datagen.flow(train_data, train_label, batch_size=64)

# %%
# Train model
checkpoint = ModelCheckpoint('./training/model-{epoch:03d}.model',monitor='val_accuracy',verbose=1,save_best_only=True,mode='auto')
History = model.fit_generator(it_train,epochs=epochs,validation_data=(val_data,val_label),callbacks=[checkpoint])
# Out:
# C:\Users\Admin\anaconda3\envs\cv2\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 66/66 [==============================] - 5s 61ms/step - loss: 0.7407 - accuracy: 0.7121 - val_loss: 0.7089 - val_accuracy: 0.5742
#
# Epoch 00001: val_accuracy improved from -inf to 0.57419, saving model to ./training\model-001.model
# INFO:tensorflow:Assets written to: ./training\model-001.model\assets
# Epoch 2/100
# 66/66 [==============================] - 4s 59ms/step - loss: 0.4724 - accuracy: 0.7817 - val_loss: 0.8590 - val_accuracy: 0.5333
#
# Epoch 00002: val_accuracy did not improve from 0.57419
# Epoch 3/100
# 66/66 [==============================] - 4s 59ms/step - loss: 0.4457 - accuracy: 0.7994 - val_loss: 1.4850 - val_accuracy: 0.5419
#
# Epoch 00003: val_accuracy did not improve from 0.57419
# Epoch 4/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.3998 - accuracy: 0.8250 - val_loss: 0.9324 - val_accuracy: 0.5462
#
# Epoch 00004: val_accuracy did not improve from 0.57419
# Epoch 5/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.3584 - accuracy: 0.8436 - val_loss: 2.0997 - val_accuracy: 0.5419
#
# Epoch 00005: val_accuracy did not improve from 0.57419
# Epoch 6/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.3250 - accuracy: 0.8577 - val_loss: 1.4846 - val_accuracy: 0.5419
#
# Epoch 00006: val_accuracy did not improve from 0.57419
# Epoch 7/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.2848 - accuracy: 0.8771 - val_loss: 0.5518 - val_accuracy: 0.7355
#
# Epoch 00007: val_accuracy improved from 0.57419 to 0.73548, saving model to ./training\model-007.model
# INFO:tensorflow:Assets written to: ./training\model-007.model\assets
# Epoch 8/100
# 66/66 [==============================] - 4s 59ms/step - loss: 0.2542 - accuracy: 0.8979 - val_loss: 0.4628 - val_accuracy: 0.8000
#
# Epoch 00008: val_accuracy improved from 0.73548 to 0.80000, saving model to ./training\model-008.model
# INFO:tensorflow:Assets written to: ./training\model-008.model\assets
# Epoch 9/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.2298 - accuracy: 0.9055 - val_loss: 0.2202 - val_accuracy: 0.9097
#
# Epoch 00009: val_accuracy improved from 0.80000 to 0.90968, saving model to ./training\model-009.model
# INFO:tensorflow:Assets written to: ./training\model-009.model\assets
# Epoch 10/100
# 66/66 [==============================] - 4s 59ms/step - loss: 0.2177 - accuracy: 0.9113 - val_loss: 0.1898 - val_accuracy: 0.9032
#
# Epoch 00010: val_accuracy did not improve from 0.90968
# Epoch 11/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.1981 - accuracy: 0.9216 - val_loss: 0.3122 - val_accuracy: 0.8602
#
# Epoch 00011: val_accuracy did not improve from 0.90968
# Epoch 12/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.2179 - accuracy: 0.9103 - val_loss: 0.2243 - val_accuracy: 0.9075
#
# Epoch 00012: val_accuracy did not improve from 0.90968
# Epoch 13/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.1807 - accuracy: 0.9206 - val_loss: 0.1811 - val_accuracy: 0.9140
#
# Epoch 00013: val_accuracy improved from 0.90968 to 0.91398, saving model to ./training\model-013.model
# INFO:tensorflow:Assets written to: ./training\model-013.model\assets
# Epoch 14/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.1601 - accuracy: 0.9376 - val_loss: 0.2630 - val_accuracy: 0.8946
#
# Epoch 00014: val_accuracy did not improve from 0.91398
# Epoch 15/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.1713 - accuracy: 0.9307 - val_loss: 0.2150 - val_accuracy: 0.9097
#
# Epoch 00015: val_accuracy did not improve from 0.91398
# Epoch 16/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.1406 - accuracy: 0.9414 - val_loss: 0.1181 - val_accuracy: 0.9462
#
# Epoch 00016: val_accuracy improved from 0.91398 to 0.94624, saving model to ./training\model-016.model
# INFO:tensorflow:Assets written to: ./training\model-016.model\assets
# Epoch 17/100
# 66/66 [==============================] - 4s 59ms/step - loss: 0.1447 - accuracy: 0.9455 - val_loss: 0.1674 - val_accuracy: 0.9355
#
# Epoch 00017: val_accuracy did not improve from 0.94624
# Epoch 18/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.1368 - accuracy: 0.9438 - val_loss: 0.1530 - val_accuracy: 0.9355
#
# Epoch 00018: val_accuracy did not improve from 0.94624
# Epoch 19/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.1382 - accuracy: 0.9469 - val_loss: 0.1643 - val_accuracy: 0.9333
#
# Epoch 00019: val_accuracy did not improve from 0.94624
# Epoch 20/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.1291 - accuracy: 0.9495 - val_loss: 0.1315 - val_accuracy: 0.9462
#
# Epoch 00020: val_accuracy did not improve from 0.94624
# Epoch 21/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.1219 - accuracy: 0.9546 - val_loss: 0.2691 - val_accuracy: 0.8860
#
# Epoch 00021: val_accuracy did not improve from 0.94624
# Epoch 22/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.1205 - accuracy: 0.9555 - val_loss: 0.1323 - val_accuracy: 0.9376
#
# Epoch 00022: val_accuracy did not improve from 0.94624
# Epoch 23/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.1108 - accuracy: 0.9608 - val_loss: 0.1941 - val_accuracy: 0.9183
#
# Epoch 00023: val_accuracy did not improve from 0.94624
# Epoch 24/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0982 - accuracy: 0.9617 - val_loss: 0.1975 - val_accuracy: 0.9269
#
# Epoch 00024: val_accuracy did not improve from 0.94624
# Epoch 25/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.1090 - accuracy: 0.9586 - val_loss: 0.1508 - val_accuracy: 0.9355
#
# Epoch 00025: val_accuracy did not improve from 0.94624
# Epoch 26/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.1054 - accuracy: 0.9615 - val_loss: 0.0841 - val_accuracy: 0.9763
#
# Epoch 00026: val_accuracy improved from 0.94624 to 0.97634, saving model to ./training\model-026.model
# INFO:tensorflow:Assets written to: ./training\model-026.model\assets
# Epoch 27/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0993 - accuracy: 0.9627 - val_loss: 0.2709 - val_accuracy: 0.8989
#
# Epoch 00027: val_accuracy did not improve from 0.97634
# Epoch 28/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.1027 - accuracy: 0.9598 - val_loss: 0.2147 - val_accuracy: 0.9161
#
# Epoch 00028: val_accuracy did not improve from 0.97634
# Epoch 29/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0927 - accuracy: 0.9658 - val_loss: 0.1700 - val_accuracy: 0.9376
#
# Epoch 00029: val_accuracy did not improve from 0.97634
# Epoch 30/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0854 - accuracy: 0.9653 - val_loss: 0.2030 - val_accuracy: 0.9204
#
# Epoch 00030: val_accuracy did not improve from 0.97634
# Epoch 31/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0884 - accuracy: 0.9646 - val_loss: 0.0679 - val_accuracy: 0.9720
#
# Epoch 00031: val_accuracy did not improve from 0.97634
# Epoch 32/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0896 - accuracy: 0.9682 - val_loss: 0.0931 - val_accuracy: 0.9591
#
# Epoch 00032: val_accuracy did not improve from 0.97634
# Epoch 33/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0795 - accuracy: 0.9692 - val_loss: 0.2776 - val_accuracy: 0.9204
#
# Epoch 00033: val_accuracy did not improve from 0.97634
# Epoch 34/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0946 - accuracy: 0.9627 - val_loss: 0.2256 - val_accuracy: 0.9161
#
# Epoch 00034: val_accuracy did not improve from 0.97634
# Epoch 35/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0809 - accuracy: 0.9682 - val_loss: 0.1613 - val_accuracy: 0.9419
#
# Epoch 00035: val_accuracy did not improve from 0.97634
# Epoch 36/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0885 - accuracy: 0.9632 - val_loss: 0.0601 - val_accuracy: 0.9742
#
# Epoch 00036: val_accuracy did not improve from 0.97634
# Epoch 37/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0770 - accuracy: 0.9675 - val_loss: 0.0915 - val_accuracy: 0.9570
#
# Epoch 00037: val_accuracy did not improve from 0.97634
# Epoch 38/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0776 - accuracy: 0.9689 - val_loss: 0.0516 - val_accuracy: 0.9849
#
# Epoch 00038: val_accuracy improved from 0.97634 to 0.98495, saving model to ./training\model-038.model
# INFO:tensorflow:Assets written to: ./training\model-038.model\assets
# Epoch 39/100
# 66/66 [==============================] - 4s 59ms/step - loss: 0.0675 - accuracy: 0.9770 - val_loss: 0.0662 - val_accuracy: 0.9720
#
# Epoch 00039: val_accuracy did not improve from 0.98495
# Epoch 40/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0753 - accuracy: 0.9737 - val_loss: 0.0828 - val_accuracy: 0.9656
#
# Epoch 00040: val_accuracy did not improve from 0.98495
# Epoch 41/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0779 - accuracy: 0.9713 - val_loss: 0.0663 - val_accuracy: 0.9742
#
# Epoch 00041: val_accuracy did not improve from 0.98495
# Epoch 42/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0821 - accuracy: 0.9663 - val_loss: 0.1888 - val_accuracy: 0.9355
#
# Epoch 00042: val_accuracy did not improve from 0.98495
# Epoch 43/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0716 - accuracy: 0.9747 - val_loss: 0.1792 - val_accuracy: 0.9290
#
# Epoch 00043: val_accuracy did not improve from 0.98495
# Epoch 44/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0605 - accuracy: 0.9780 - val_loss: 0.2645 - val_accuracy: 0.9183
#
# Epoch 00044: val_accuracy did not improve from 0.98495
# Epoch 45/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0652 - accuracy: 0.9780 - val_loss: 0.1166 - val_accuracy: 0.9634
#
# Epoch 00045: val_accuracy did not improve from 0.98495
# Epoch 46/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0669 - accuracy: 0.9737 - val_loss: 0.0805 - val_accuracy: 0.9677
#
# Epoch 00046: val_accuracy did not improve from 0.98495
# Epoch 47/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0595 - accuracy: 0.9778 - val_loss: 0.0966 - val_accuracy: 0.9591
#
# Epoch 00047: val_accuracy did not improve from 0.98495
# Epoch 48/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0538 - accuracy: 0.9799 - val_loss: 0.2884 - val_accuracy: 0.9032
#
# Epoch 00048: val_accuracy did not improve from 0.98495
# Epoch 49/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0575 - accuracy: 0.9802 - val_loss: 0.0785 - val_accuracy: 0.9656
#
# Epoch 00049: val_accuracy did not improve from 0.98495
# Epoch 50/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0809 - accuracy: 0.9723 - val_loss: 0.1168 - val_accuracy: 0.9484
#
# Epoch 00050: val_accuracy did not improve from 0.98495
# Epoch 51/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0735 - accuracy: 0.9720 - val_loss: 0.1500 - val_accuracy: 0.9398
#
# Epoch 00051: val_accuracy did not improve from 0.98495
# Epoch 52/100
# 66/66 [==============================] - 4s 62ms/step - loss: 0.0647 - accuracy: 0.9756 - val_loss: 0.1568 - val_accuracy: 0.9484
#
# Epoch 00052: val_accuracy did not improve from 0.98495
# Epoch 53/100
# 66/66 [==============================] - 4s 65ms/step - loss: 0.0587 - accuracy: 0.9723 - val_loss: 0.0527 - val_accuracy: 0.9742
#
# Epoch 00053: val_accuracy did not improve from 0.98495
# Epoch 54/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0617 - accuracy: 0.9768 - val_loss: 0.0952 - val_accuracy: 0.9699
#
# Epoch 00054: val_accuracy did not improve from 0.98495
# Epoch 55/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0596 - accuracy: 0.9775 - val_loss: 0.0415 - val_accuracy: 0.9828
#
# Epoch 00055: val_accuracy did not improve from 0.98495
# Epoch 56/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0559 - accuracy: 0.9804 - val_loss: 0.0569 - val_accuracy: 0.9828
#
# Epoch 00056: val_accuracy did not improve from 0.98495
# Epoch 57/100
# 66/66 [==============================] - 4s 62ms/step - loss: 0.0464 - accuracy: 0.9809 - val_loss: 0.0388 - val_accuracy: 0.9871
#
# Epoch 00057: val_accuracy improved from 0.98495 to 0.98710, saving model to ./training\model-057.model
# INFO:tensorflow:Assets written to: ./training\model-057.model\assets
# Epoch 58/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0593 - accuracy: 0.9792 - val_loss: 0.0649 - val_accuracy: 0.9699
#
# Epoch 00058: val_accuracy did not improve from 0.98710
# Epoch 59/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0458 - accuracy: 0.9830 - val_loss: 0.0517 - val_accuracy: 0.9763
#
# Epoch 00059: val_accuracy did not improve from 0.98710
# Epoch 60/100
# 66/66 [==============================] - 4s 62ms/step - loss: 0.0640 - accuracy: 0.9778 - val_loss: 0.2545 - val_accuracy: 0.9204
#
# Epoch 00060: val_accuracy did not improve from 0.98710
# Epoch 61/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0576 - accuracy: 0.9794 - val_loss: 0.1342 - val_accuracy: 0.9484
#
# Epoch 00061: val_accuracy did not improve from 0.98710
# Epoch 62/100
# 66/66 [==============================] - 4s 62ms/step - loss: 0.0583 - accuracy: 0.9780 - val_loss: 0.0343 - val_accuracy: 0.9892
#
# Epoch 00062: val_accuracy improved from 0.98710 to 0.98925, saving model to ./training\model-062.model
# INFO:tensorflow:Assets written to: ./training\model-062.model\assets
# Epoch 63/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0480 - accuracy: 0.9840 - val_loss: 0.1027 - val_accuracy: 0.9613
#
# Epoch 00063: val_accuracy did not improve from 0.98925
# Epoch 64/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0455 - accuracy: 0.9828 - val_loss: 0.2028 - val_accuracy: 0.9376
#
# Epoch 00064: val_accuracy did not improve from 0.98925
# Epoch 65/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0455 - accuracy: 0.9845 - val_loss: 0.0323 - val_accuracy: 0.9914
#
# Epoch 00065: val_accuracy improved from 0.98925 to 0.99140, saving model to ./training\model-065.model
# INFO:tensorflow:Assets written to: ./training\model-065.model\assets
# Epoch 66/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0439 - accuracy: 0.9830 - val_loss: 0.2670 - val_accuracy: 0.9247
#
# Epoch 00066: val_accuracy did not improve from 0.99140
# Epoch 67/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.1865 - accuracy: 0.9381 - val_loss: 0.4157 - val_accuracy: 0.7935
#
# Epoch 00067: val_accuracy did not improve from 0.99140
# Epoch 68/100
# 66/66 [==============================] - 4s 59ms/step - loss: 0.1037 - accuracy: 0.9615 - val_loss: 0.3671 - val_accuracy: 0.8387
#
# Epoch 00068: val_accuracy did not improve from 0.99140
# Epoch 69/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0845 - accuracy: 0.9687 - val_loss: 0.1085 - val_accuracy: 0.9656
#
# Epoch 00069: val_accuracy did not improve from 0.99140
# Epoch 70/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0739 - accuracy: 0.9718 - val_loss: 0.1210 - val_accuracy: 0.9527
#
# Epoch 00070: val_accuracy did not improve from 0.99140
# Epoch 71/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0680 - accuracy: 0.9737 - val_loss: 1.2284 - val_accuracy: 0.7398
#
# Epoch 00071: val_accuracy did not improve from 0.99140
# Epoch 72/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0602 - accuracy: 0.9778 - val_loss: 0.0509 - val_accuracy: 0.9763
#
# Epoch 00072: val_accuracy did not improve from 0.99140
# Epoch 73/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0428 - accuracy: 0.9828 - val_loss: 0.0419 - val_accuracy: 0.9828
#
# Epoch 00073: val_accuracy did not improve from 0.99140
# Epoch 74/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0509 - accuracy: 0.9804 - val_loss: 0.0386 - val_accuracy: 0.9914
#
# Epoch 00074: val_accuracy did not improve from 0.99140
# Epoch 75/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0521 - accuracy: 0.9797 - val_loss: 0.0705 - val_accuracy: 0.9720
#
# Epoch 00075: val_accuracy did not improve from 0.99140
# Epoch 76/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0501 - accuracy: 0.9825 - val_loss: 0.0430 - val_accuracy: 0.9892
#
# Epoch 00076: val_accuracy did not improve from 0.99140
# Epoch 77/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0393 - accuracy: 0.9845 - val_loss: 0.0638 - val_accuracy: 0.9806
#
# Epoch 00077: val_accuracy did not improve from 0.99140
# Epoch 78/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0331 - accuracy: 0.9878 - val_loss: 0.0578 - val_accuracy: 0.9806
#
# Epoch 00078: val_accuracy did not improve from 0.99140
# Epoch 79/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0545 - accuracy: 0.9802 - val_loss: 0.1085 - val_accuracy: 0.9548
#
# Epoch 00079: val_accuracy did not improve from 0.99140
# Epoch 80/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0544 - accuracy: 0.9809 - val_loss: 0.1184 - val_accuracy: 0.9699
#
# Epoch 00080: val_accuracy did not improve from 0.99140
# Epoch 81/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0417 - accuracy: 0.9873 - val_loss: 0.1930 - val_accuracy: 0.9419
#
# Epoch 00081: val_accuracy did not improve from 0.99140
# Epoch 82/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0457 - accuracy: 0.9828 - val_loss: 0.1715 - val_accuracy: 0.9441
#
# Epoch 00082: val_accuracy did not improve from 0.99140
# Epoch 83/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0413 - accuracy: 0.9840 - val_loss: 0.3620 - val_accuracy: 0.8645
#
# Epoch 00083: val_accuracy did not improve from 0.99140
# Epoch 84/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0414 - accuracy: 0.9866 - val_loss: 0.0772 - val_accuracy: 0.9742
#
# Epoch 00084: val_accuracy did not improve from 0.99140
# Epoch 85/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0359 - accuracy: 0.9876 - val_loss: 0.0460 - val_accuracy: 0.9806
#
# Epoch 00085: val_accuracy did not improve from 0.99140
# Epoch 86/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0322 - accuracy: 0.9876 - val_loss: 0.0592 - val_accuracy: 0.9785
#
# Epoch 00086: val_accuracy did not improve from 0.99140
# Epoch 87/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0293 - accuracy: 0.9888 - val_loss: 0.0610 - val_accuracy: 0.9763
#
# Epoch 00087: val_accuracy did not improve from 0.99140
# Epoch 88/100
# 66/66 [==============================] - 4s 59ms/step - loss: 0.0472 - accuracy: 0.9809 - val_loss: 0.0798 - val_accuracy: 0.9785
#
# Epoch 00088: val_accuracy did not improve from 0.99140
# Epoch 89/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0444 - accuracy: 0.9821 - val_loss: 0.2400 - val_accuracy: 0.9226
#
# Epoch 00089: val_accuracy did not improve from 0.99140
# Epoch 90/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0487 - accuracy: 0.9806 - val_loss: 0.0628 - val_accuracy: 0.9763
#
# Epoch 00090: val_accuracy did not improve from 0.99140
# Epoch 91/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0397 - accuracy: 0.9837 - val_loss: 0.0483 - val_accuracy: 0.9785
#
# Epoch 00091: val_accuracy did not improve from 0.99140
# Epoch 92/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0481 - accuracy: 0.9840 - val_loss: 0.0700 - val_accuracy: 0.9785
#
# Epoch 00092: val_accuracy did not improve from 0.99140
# Epoch 93/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0387 - accuracy: 0.9866 - val_loss: 0.0566 - val_accuracy: 0.9763
#
# Epoch 00093: val_accuracy did not improve from 0.99140
# Epoch 94/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0226 - accuracy: 0.9921 - val_loss: 0.0363 - val_accuracy: 0.9914
#
# Epoch 00094: val_accuracy did not improve from 0.99140
# Epoch 95/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0284 - accuracy: 0.9902 - val_loss: 0.0485 - val_accuracy: 0.9871
#
# Epoch 00095: val_accuracy did not improve from 0.99140
# Epoch 96/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0453 - accuracy: 0.9854 - val_loss: 0.0426 - val_accuracy: 0.9806
#
# Epoch 00096: val_accuracy did not improve from 0.99140
# Epoch 97/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0474 - accuracy: 0.9825 - val_loss: 0.2451 - val_accuracy: 0.9204
#
# Epoch 00097: val_accuracy did not improve from 0.99140
# Epoch 98/100
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0343 - accuracy: 0.9880 - val_loss: 0.0884 - val_accuracy: 0.9505
#
# Epoch 00098: val_accuracy did not improve from 0.99140
# Epoch 99/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0469 - accuracy: 0.9825 - val_loss: 0.0651 - val_accuracy: 0.9720
#
# Epoch 00099: val_accuracy did not improve from 0.99140
# Epoch 100/100
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0521 - accuracy: 0.9785 - val_loss: 0.0892 - val_accuracy: 0.9613
#
# Epoch 00100: val_accuracy did not improve from 0.99140

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 94, 94, 32)        320
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 94, 94, 32)        128
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 92, 92, 32)        9248
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 92, 92, 32)        128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 46, 46, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 46, 46, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 44, 44, 64)        18496
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 44, 44, 64)        256
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 42, 42, 64)        36928
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 42, 42, 64)        256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 21, 21, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 21, 21, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 28224)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               7225600
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 7,292,898
# Trainable params: 7,292,002
# Non-trainable params: 896
# _________________________________________________________________

# %%
# load model
model = load_model('./training\model-065.model')
# Test with Test data
score = model.evaluate(test_data, test_label, verbose=1)
print(score)
# Out:
# 17/17 [==============================] - 8s 17ms/step - loss: 0.0201 - accuracy: 0.9961
# [0.02014726772904396, 0.9961315393447876]

# %%
y_pred = model.predict(test_data)
y_pred = np.argmax(y_pred,axis = 1)

# %%
y_test = np.argmax(test_label,axis = 1)
X = np.asarray(y_test != y_pred).reshape(517)
X_wrong = test_data[X]
y_wrong = y_pred[y_test != y_pred]

print(np.sum(y_test != y_pred))
plt.figure(figsize = (20,20))
plt.grid(None)
for i in range(2):
    plt.subplot(1, 6, i+1)
    plt.imshow((X_wrong[i]),cmap = "gray")
    j = y_wrong[i]
    plt.title(f"Dự đoán: {categories[j]}")
# Out:
# 2
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7540\2536699914.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 6, i+1)

# %%
# Save model
model.save('gender_detection.model')
# Out:
# INFO:tensorflow:Assets written to: gender_detection.model\assets

# %%
#Plot Training Loss and Accuracy
plt.style.use("ggplot")
plt.figure()
N = epochs

plt.plot(np.arange(0,N), History.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), History.history["val_loss"], label="val_loss")
plt.plot(np.arange(0,N), History.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0,N), History.history["val_accuracy"], label="val_accracy")

plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper right");

# %%
import numpy as np
import cv2
import os
import cvlib as cv
                    
# open webcam
capture = cv2.VideoCapture(0)
    
classes = ['man','woman']

# loop through frames
while capture.isOpened():

    # read frame from webcam 
    status, frame = capture.read()
    
    # apply face detection
    face, confidence = cv.detect_face(frame)
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)


    # loop through detected faces
    for idx, f in enumerate(face):
        
        # get corner points of face rectangle        
        (startX, startY) = f[0], f[1]
        (endX, endY) = f[2], f[3]

        # draw rectangle over face
        cv2.rectangle(frame, (startX,startY), (endX,endY), (0,255,0), 2)

        # crop the detected face region
        face_crop = np.copy(gray[startY:endY,startX:endX])
        
        

        if (face_crop.shape[0]) < 10 or (face_crop.shape[1]) < 10:
            continue

        # preprocessing for gender detection model
        face_crop = cv2.resize(face_crop, (96,96))
        face_crop = face_crop/ 255.0
        face_crop = face_crop.reshape((1,96,96,1))
        

        # apply gender detection on face
        conf = model.predict(face_crop)[0] # model.predict return a 2D matrix, ex: [[9.9993384e-01 7.4850512e-05]]

        # get label with max accuracy
        idx = np.argmax(conf)
        label = classes[idx]

        label = "{}: {:.2f}%".format(label, conf[idx] * 100)


        Y = startY - 10 if startY - 10 > 10 else startY + 10

        # write label and confidence above face rectangle
        cv2.putText(frame, label, (startX, Y),  cv2.FONT_HERSHEY_SIMPLEX,
                    0.7, (0, 255, 0), 2)

    # display output
    cv2.imshow("gender detection", frame)

    # press "Q" to stop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# release resources
capture.release()
cv2.destroyAllWindows()

# %%
# Exit webcam immediately
capture.release()
cv2.destroyAllWindows()
cv2.waitKey(0)
# Out:
# -1

# %%
git init
# Out:
#   Input In [9]
#     git init
#         ^
# SyntaxError: invalid syntax
